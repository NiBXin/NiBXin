5qcjnd%2fboRRVE2Jjf0YgNWuuJh%2fipvTgJRg5tdSoSGET927LqfYYLb1TKC6EKfk1mTvEX3zSFKePklSMF3liLsstllEZd6G7r1ardfUX%2f3%2bepU%3d; pd0=KlEX2KgcU%2fvhDlWXmQ4SjkUlwLlkQ2gW0ZUiIilfowf1zyxolmHrYvlniSA8ZVMNTB6L0Ed7egt2WsDSAob3TA7s6z%2fr%2bSdGQ0P9R%2fZ0GTR%2b8%2fE69X89SaAoMgnZaFrm2wULOKtkizcqpR4FbCexerd3qZFCUI6PYsxYrRUP%2fGEL0PBNqVi0xdvgtx7CvYEMcc%2bsowf0AEIaQQj44sZ7oGF0CvTA8hFq59BYI%2bQzKGBsT7q2GiZJN4XWtgPhDo4Z2a01MvSjFFaUkqLu2VoFFuDh5ToV2rWdQ3AQe%2b80MDsdm0KgkB3NHR4z77tywPFD4B7HpCRbb9chI4gPijt56jQpMXm2wq7Fk7EbJeAAuvJLTxhO2EQnZ2RlL28Q6OMVhKYMKwzoLkMJ0ke7UNq6ZokAsvoVVsSP5bCjOLknpx1IgcGW7f7GauBRXcZHSGogdr4Ho%2f1jGS4tri7Xmn96IKrON%2b3FN9IfIq60xXjuG0mhzSwv9qKVq6axyTTEvQRh9P0hWhK7jY%2bb%2fVY9rT0fWf%2flufVIvvJ1IiasJ9zwnAAJf08rG3nHAZEEGK2jHBTgFVg5vCq6ABHXX47TYmFIsPwZBwfmsrA3qfdx9P%2fYpjjSQRBcT2bA1edYmIdhcPyyUI9IgXkMrkt0Mf5gDmTYE%2b7O66ypnxPMXFQnfv8KVP9GVspYGFiy0A1%2ftifpWpQt; bm_sv=F1FABB4BA7C2EFA93E7BB94B5B730641~~1; s_nr=1726791678117-Repeat",
        'priority': 'u=1, i',
        'referer': 'https://www2.commsec.com.au/quotes/summary?stockCode=BHD&exchangeCode=ASX',
        'sec-ch-ua': '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36',
    }

    params = {
        'securityCode': code,
    }

    response = requests.get(
        'https://www2.commsec.com.au/quotes/api/v1/marketinfo/prices',
        params=params,
        cookies=cookies,
        headers=headers,
    )
    return response

# %%
data = response.json()

# %%
for i in data['marketDepthPrices']:
    print(i)
# Out:
# prices
# totalBuyOrders
# totalBuyVolume
# totalSellOrders
# totalSellVolume
# currentDateTime

# %%
codes = pd.read_excel(r"C:\Users\N\Downloads\bid_offer_2.xlsx", sheet_name='Sheet2')
codes = codes.dropna(axis=0,how='any')

# %%
codes.head(10)
# Out:
#   ASX code
# 0      AIV
# 1      MTB
# 2      CLZ
# 3      DMG
# 4      C1X
# 5      DBO
# 6      LRD
# 7      NES
# 8      AS2
# 9      AMM

# %%
data = catach_volum(code).json()

# %%
data_total = {}

for code in codes['ASX code']:
    code_info = {}
    max_volum = -1
    max_n = -1
    max_price = -1
    deal_1 = -1
    totalBuyOrders = -1
    totalBuyVolume = -1
    totalSellOrders = -1
    totalSellVolume = -1
    print(code)
    try:
        data = catach_volum(code).json()
        for deal in data['marketDepthPrices']['prices']:
            index = data['marketDepthPrices']['prices'].index(deal)
            if index == 0:
                print(deal)
                deal_1 = deal
            if deal['buyVolume']!=None:
                max_volum = max(max_volum, int(deal['buyVolume']))
                if max_volum == deal['buyVolume']:
                    max_n = deal['buyNumber']
                    max_price = deal['buyPrice']
    except  Exception as error:
        print("An exception occurred:", error)
        print('no data')
    print(max_volum)
    try:
        totalBuyOrders = data['marketDepthPrices']['totalBuyOrders']
        totalBuyVolume = data['marketDepthPrices']['totalBuyVolume']
        totalSellOrders = data['marketDepthPrices']['totalSellOrders']
        totalSellVolume = data['marketDepthPrices']['totalSellVolume']
        print(totalBuyOrders)
        print(totalBuyVolume)
        print(totalSellOrders)
        print(totalSellVolume)
        
    except  Exception as error:
        print("An exception occurred:", error)
        print('no data')
    if max_volum == -1:
        max_volum = '-'
    if totalBuyOrders == -1:
        totalBuyOrders = '-'
    if totalBuyVolume == -1:
        totalBuyVolume = '-'
    if totalSellOrders == -1:
        totalSellOrders = '-'
    if totalSellVolume == -1:
        totalSellVolume = '-'
    if max_n == -1:
        max_n = '-'
    if max_price == -1:
        max_price = '-'
#     code_info['first_info'] = deal_1
    if deal_1 != -1:
        code_info['buyNumber_1'] = deal_1['buyNumber']
        code_info['buyVolume_1'] = deal_1['buyVolume']
        code_info['buyPrice_1'] = deal_1['buyPrice'] 
        code_info['sellNumber_1'] = deal_1['sellNumber']
        code_info['sellVolume_1'] = deal_1['sellVolume']
        code_info['sellPrice_1'] = deal_1['sellPrice']
    else:
        code_info['buyNumber_1'] = '-'
        code_info['buyVolume_1'] = '-'
        code_info['buyPrice_1'] = '-'
        code_info['sellNumber_1'] = '-'
        code_info['sellVolume_1'] = '-'
        code_info['sellPrice_1'] = '-'
    code_info['max_v'] = max_volum
    code_info['max_n'] = max_n
    code_info['max_p'] = max_price
    code_info['totalBuyOrders'] = totalBuyOrders
    code_info['totalBuyVolume'] = totalBuyVolume
    code_info['totalSellOrders'] = totalSellOrders
    code_info['totalSellVolume'] = totalSellVolume
    data_total[code] = code_info
    #     BCB
# Out:
# AIV
# {'buyNumber': 5, 'buyVolume': 278127, 'buyPrice': 0.006, 'sellNumber': 2, 'sellVolume': 30005, 'sellPrice': 0.01}
# 1728104
# 20
# 5774859
# 10
# 682704
# MTB
# {'buyNumber': 35, 'buyVolume': 90677233, 'buyPrice': 0.001, 'sellNumber': 17, 'sellVolume': 41264314, 'sellPrice': 0.002}
# 90677233
# 35
# 90677233
# 74
# 75352527
# CLZ
# {'buyNumber': None, 'buyVolume': None, 'buyPrice': None, 'sellNumber': 42, 'sellVolume': 266858605, 'sellPrice': 0.001}
# -1
# 0
# 0
# 94
# 348234992
# DMG
# {'buyNumber': 4, 'buyVolume': 338297, 'buyPrice': 0.006, 'sellNumber': 2, 'sellVolume': 203544, 'sellPrice': 0.018}
# 2375222
# 22
# 7254294
# 10
# 1362635
# C1X
# {'buyNumber': 2, 'buyVolume': 87718, 'buyPrice': 0.037, 'sellNumber': 3, 'sellVolume': 35639, 'sellPrice': 0.047}
# 796000
# 15
# 1399292
# 12
# 602434
# DBO
# {'buyNumber': 4, 'buyVolume': 352643, 'buyPrice': 0.016, 'sellNumber': 5, 'sellVolume': 155138, 'sellPrice': 0.019}
# 709014
# 31
# 3271506
# 24
# 1904457
# LRD
# ...

# %%
data_total
# Out:
# {'AIV': {'buyNumber_1': 5,
#   'buyVolume_1': 278127,
#   'buyPrice_1': 0.006,
#   'sellNumber_1': 2,
#   'sellVolume_1': 30005,
#   'sellPrice_1': 0.01,
#   'max_v': 1728104,
#   'max_n': 3,
#   'max_p': 0.001,
#   'totalBuyOrders': 20,
#   'totalBuyVolume': 5774859,
#   'totalSellOrders': 10,
#   'totalSellVolume': 682704},
#  'MTB': {'buyNumber_1': 35,
#   'buyVolume_1': 90677233,
#   'buyPrice_1': 0.001,
#   'sellNumber_1': 17,
#   'sellVolume_1': 41264314,
#   'sellPrice_1': 0.002,
#   'max_v': 90677233,
#   'max_n': 35,
#   'max_p': 0.001,
#   'totalBuyOrders': 35,
#   'totalBuyVolume': 90677233,
#   'totalSellOrders': 74,
#   'totalSellVolume': 75352527},
#  'CLZ': {'buyNumber_1': None,
#   'buyVolume_1': None,
#   'buyPrice_1': None,
#   'sellNumber_1': 42,
#   'sellVolume_1': 266858605,
#   'sellPrice_1': 0.001,
#   'max_v': '-',
#   'max_n': '-',
#   'max_p': '-',
#   'totalBuyOrders': 0,
#   'totalBuyVolume': 0,
#   'totalSellOrders': 94,
# ...

# %%
final_list = [['code','buyNumber_1','buyVolume_1','buyPrice_1','sellNumber_1','sellVolume_1','sellPrice_1','max_n','max_v','max_p','totalBuyOrders','totalBuyVolume','totalSellOrders','totalSellVolume']]
for i in data_total:
#     print(i)
    list1 = []
    list1.append(i)
    list1.append(data_total[i]['buyNumber_1'])
    list1.append(data_total[i]['buyVolume_1'])
    list1.append(data_total[i]['buyPrice_1'])
    list1.append(data_total[i]['sellNumber_1'])
    list1.append(data_total[i]['sellVolume_1'])
    list1.append(data_total[i]['sellPrice_1'])
    list1.append(data_total[i]['max_n'])
    list1.append(data_total[i]['max_v'])
    list1.append(data_total[i]['max_p'])
    list1.append(data_total[i]['totalBuyOrders'])    
    list1.append(data_total[i]['totalBuyVolume'])    
    list1.append(data_total[i]['totalSellOrders'])    
    list1.append(data_total[i]['totalSellVolume'])    
    final_list.append(list1)

# %%
final_data = pd.DataFrame(final_list)
# final_data
final_data.to_excel(r"C:\Users\N\Downloads\buyer_volum.xlsx",sheet_name='Sheet1')
