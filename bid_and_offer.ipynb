# %%
import requests
import pandas as pd
import time

# %%
def catch_bid_info(code):
    cookies = {
        'aam_uuid': '82571235217056239480648528720939777148',
        '_gcl_au': '1.1.1140494983.1721774899',
        '_fbp': 'fb.2.1721774899633.354363634452428271',
        '_CommSecTracker': 'SBJTMv7riN3eWaX2cjAhUJBSb3u',
        'kndctr_FFF9306152D80A5C0A490D45_AdobeOrg_identity': 'CiY4Mjc1NzExNTk1Mzc1Mzc5ODIwMDY3MDQ3NDE0NTA0MzU3Njk4OFIRCNyozcGQMhgBKgRBVVMzMAHwAdyozcGQMg==',
        'AMCV_FFF9306152D80A5C0A490D45%40AdobeOrg': 'MCMID|82757115953753798200670474145043576988',
        's_pvt_ev47': '%5B%5B%27Typed%2FBookmarked%27%2C%271722908974273%27%5D%2C%5B%27Other%2520Natural%2520Referrers%27%2C%271723517365929%27%5D%2C%5B%27Typed%2FBookmarked%27%2C%271723526312442%27%5D%2C%5B%27Other%2520Natural%2520Referrers%27%2C%271723682357206%27%5D%5D',
        's_pvt_ev48': '%5B%5B%27Typed%2FBookmarked%27%2C%271722908974274%27%5D%2C%5B%27Other%2520Natural%2520Referrers%27%2C%271723517365930%27%5D%2C%5B%27Typed%2FBookmarked%27%2C%271723526312442%27%5D%2C%5B%27Other%2520Natural%2520Referrers%27%2C%271723682357207%27%5D%5D',
        's_pvt_ev49': '%5B%5B%27Typed%2FBookmarked%27%2C%271722908974275%27%5D%2C%5B%27Other%2520Natural%2520Referrers%27%2C%271723517365931%27%5D%2C%5B%27Typed%2FBookmarked%27%2C%271723526312443%27%5D%2C%5B%27Other%2520Natural%2520Referrers%27%2C%271723682357207%27%5D%5D',
        'kndctr_CB513704532E6DD00A490D44_AdobeOrg_identity': 'CiY4Mjc5NDk0MjY4MDYxNTg1MDQ1MDY4MDQ5MTQ0MTE3OTg2NTk1N1IRCNn-lKibMhgBKgRBVVMzMAPwAZ20rKSeMg==',
        'AMCVS_CB513704532E6DD00A490D44%40AdobeOrg': '1',
        's_cc': 'true',
        'at_check': 'true',
        'return_url_key': '-1%7c%2fPublic%2fHomePage%2fExternal%2fLiveSession.aspx%3fts%3d45548.40179564815',
        's_pvt_v5': 'loginbutton-cus-unt-eng-pen-pulibu-20210805-1',
        '3720%5F1%5FPYLD': 'YYY711_jVmjbEbMz6vdarvIjgfTR8gBl9bUe77FSlUWO4d34XoW7FGnY3rlVC643mv%2BraJZi9XheaOgVWusPDOhsGHTspEvwNUiSqZlVlfLEwiY%2FP48kl9EE8o2YizKRN6WQX27o67cCa0S51XAJNyJYhUvnWLrtOoBpqVx4YX2ONCmcTONgTViL8yK4lAvMTVg1eNpApOrVSGLXM9VYGOn6fxGud7SDzdcK34Vl%2FbllRvoftCk3iRkFGOpf8M%2BQhBJPJNEOlMjdv5O%2Bp8%3D',
        '3720%5F1': 'YYY711_jWhcU%2FFVTrkZpl6xUKuMwQ%3D%3D',
        'ModToken': '0007Teykx5Dkangw4PrSOld4nGdf-SBJTMv7riN3eWaX2cjAhUJBSb3u-2024-09-13T05:42:07Z',
        '__RequestVerificationToken_L1F1b3Rlcw2': 'Nx8GYy3lCwGVY761wbpEK99IlNNrAIKGINVPHusmXYFPgck16iMjw_guGv-MNNDti3E0jEU_LnKvIiYs55tO-EkV_0jJtVB_Jp4alad4mBA1',
        'MODJSONWebToken': '0007Teykx5Dkangw4PrSOld4nGdf',
        'provider': '',
sec-ch-ua': '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36',
    }

    params = {
        'securityCode': code,
        'exchangeCode': 'ASX',
    }

    response = requests.get(
        'https://www2.commsec.com.au/quotes/api/v1/marketinfo/overview',
        params=params,
        cookies=cookies,
        headers=headers,
    )
    return response

# %%
codes = pd.read_excel(r"C:\Users\N\Downloads\bid_offer_list1.xlsx", sheet_name='Missing')

# %%
codes
# Out:
#      ASX
# 0    14D
# 1    4DS
# 2    5GG
# 3    88E
# 4    8CO
# ..   ...
# 111  VHM
# 112  VML
# 113  VNL
# 114  WAK
# 115  WML
#
# [116 rows x 1 columns]

# %%
ASX = {}
for i in range(0,codes.shape[0]):
    b_o_list = {}
    offer = '-'
    bid = '-'
    code = codes.iloc[i]['ASX']
    mat = [['Company Name','Ticker','Last price','Market Cap','Last price_d','Market Cap_d']]
    try:
        bid_offer = catch_bid_info(code).json()
        offer = bid_offer['overview']['ask']
        bid = bid_offer['overview']['bid']
    except Exception as error:
        print("An exception occurred:", error)
    b_o_list['bid'] = bid
    b_o_list['offer'] = offer
    ASX[code] = b_o_list
    time.sleep(0.05)
    print(code)
# Out:
# 14D
# 4DS
# 5GG
# 88E
# 8CO
# A8G
# AAM
# AAR
# ACR
# AKN
# AL3
# AMD
# AMN
# AN1
# AQN
# ASQ
# AUN
# AWJ
# AXI
# BCC
# BCK
# BDX
# BM8
# BPH
# BSA
# BTR
# BVR
# BYH
# CBE
# CDR
# CGR
# CLU
# CMG
# CRR
# CTN
# CUS
# CWX
# CYQ
# DBO
# DCC
# DEM
# DOC
# EAX
# EMT
# FBM
# GML
# GUE
# HCD
# HMG
# HMI
# ICG
# ION
# IR1
# IRD
# IVR
# KAI
# KRR
# KZR
# LBT
# LGP
# LMS
# LSA
# MAG
# MEG
# MEU
# MKG
# MPA
# MQR
# MTL
# MXR
# NC1
# NIS
# NNL
# NSB
# NUC
# NXS
# OEC
# ONE
# OSM
# PCK
# PCL
# PEK
# PIQ
# PL3
# PV1
# QHL
# RIL
# RIM
# RML
# RSH
# S2R
# SCL
# SES
# SIV
# SLB
# SMS
# SNX
# SP3
# SUH
# SVY
# TAR
# TFL
# TG1
# TLM
# TMS
# TOU
# TVN
# TYX
# USL
# VEN
# VFX
# VHM
# VML
# VNL
# WAK
# WML

# %%
codes['bid']=0
codes['offer'] = 0

# %%
codes
# Out:
#      ASX  bid  offer
# 0    14D    0      0
# 1    4DS    0      0
# 2    5GG    0      0
# 3    88E    0      0
# 4    8CO    0      0
# ..   ...  ...    ...
# 111  VHM    0      0
# 112  VML    0      0
# 113  VNL    0      0
# 114  WAK    0      0
# 115  WML    0      0
#
# [116 rows x 3 columns]

# %%
final_code = codes
for i in range(0,codes['ASX'].shape[0]):
    code = codes.iloc[i,0]
#     print(final_code.iloc[i,0])
    final_code.iloc[i,1] = ASX[code]['bid']
    final_code.iloc[i,2] = ASX[code]['offer']
#     print(code)
#     print(final_code.iloc[i][2])

# %%
final_code.to_excel(r"C:\Users\N\Downloads\bid_offer_1.xlsx",sheet_name='Sheet1')
